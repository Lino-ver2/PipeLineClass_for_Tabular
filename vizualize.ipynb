# %% [markdown]
# ### 狭心症
# 原因はほとんど動脈硬化（血管老化現象->ageと関係あり）<br>
# コレステロール
# >
# 2種類ある
# - 労作性狭心症 -> 運動によるもの
# - 攣縮縮性(かんれんせい)狭心症 -> 喫煙、飲酒、ストレス、寒冷刺激<br>
# [参考ページ](https://hidamari-naika.jp/treatment/angina.html#:~:text=%E7%8B%AD%E5%BF%83%E7%97%87%E3%81%AB%E3%81%AF,%E5%9C%A7%E8%BF%AB%E6%84%9F%E3%82%92%E8%A6%9A%E3%81%88%E3%81%BE%E3%81%99%E3%80%82)<br>
# >
# ChestPainType(筋痛の種類)
# 狭心症について
# - がん・脳卒中とならぶ3大死因要因の一つ(高齢者に多い) -> ageに相関?
# - 食生活・運動不足・喫煙などの生活習慣が関係 -> Cholesterolに関係があるかも
# -

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./data/train.csv')
data.head(5)
# Out:
#    Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0   56    1           ASY        155          342          1     Normal
# 1   55    0           ATA        130          394          0        LVH
# 2   47    1           NAP        110            0          1     Normal
# 3   34    1           ASY        115            0          1     Normal
# 4   54    0           NAP        160          201          0     Normal
#
#    MaxHR  ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0    150               1      3.0     Flat             1
# 1    150               0      0.0       Up             0
# 2    120               1      0.0     Flat             1
# 3    154               0      0.2       Up             1
# 4    163               0      0.0       Up             0

# %%
data[data.HeartDisease == 1].count()
# Out:
# Age               359
# Sex               359
# ChestPainType     359
# RestingBP         359
# Cholesterol       359
# FastingBS         359
# RestingECG        359
# MaxHR             359
# ExerciseAngina    359
# Oldpeak           359
# ST_Slope          359
# HeartDisease      359
# dtype: int64

# %%
data[data['HeartDisease']==0].ChestPainType.value_counts()
# Out:
# ATA    105
# NAP     95
# ASY     69
# TA      14
# Name: ChestPainType, dtype: int64

# %%
def corr(cidx, mode='hist'):
    cat = ['ChestPainType', 'RestingECG', 'ST_Slope', 'HeartDisease']
    pair_data = data[['RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']+[cat[cidx]]]
    sns.pairplot(pair_data, diag_kind=mode,  hue=cat[cidx])

# %%
plt.figure(figsize=(6,3))
sns.histplot(df.Age)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(6,3))
sns.histplot(df.RestingBP)
# Out:
# <AxesSubplot:xlabel='RestingBP', ylabel='Count'>

# %%
plt.figure(figsize=(6,3))
sns.histplot(df.Cholesterol)
# Out:
# <AxesSubplot:xlabel='Cholesterol', ylabel='Count'>

# %%
corr(3)
