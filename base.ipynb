# %%
import numpy as np
import pandas as pd

from sklearn.svm import SVC

from mymodule import PipeLine, evaluations

# %%
# 使用するデータセット
df = pd.read_csv('./data/train.csv')
df.head(3)
# Out:
#    Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0   56    1           ASY        155          342          1     Normal
# 1   55    0           ATA        130          394          0        LVH
# 2   47    1           NAP        110            0          1     Normal
#
#    MaxHR  ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0    150               1      3.0     Flat             1
# 1    150               0      0.0       Up             0
# 2    120               1      0.0     Flat             1

# %% [markdown]
# >
# # ベースラインの作成
# ベースラインを作成して今後の特徴作成やモデル選択の比較対象とする<br>
# カテゴリ変数と欠損の多いコレステロール値のカラムを除いたものとする
# モデルは線形分離モデルのSVCを使用

# %%
df = pd.read_csv('./data/train.csv')

# 前処理
pipe = PipeLine()
pipe(df)
pipe.df_num = pipe.df_num.drop(['Cholesterol'], axis=1)
print('-'*20, ' ベースラインで使用する変数', '-'*20)
display(pipe.df_num.head(3))
# 7:3でデータを分割(seed値はpipe.random_seed=scala: intで設定)
pack = pipe.fold_out_split(test_size=0.3)  # x_train, x_test, y_train, y_test = pack

# サポートベクターマシンでモデルを訓練
model = SVC()
model.fit(pack[0], pack[2])

# 予測値を出力
print()
print('-'*20, '性能評価', '-'*20)
display(evaluations(model, *pack))
# Out:
# --------------------  ベースラインで使用する変数 --------------------
#    Age  Sex  RestingBP  FastingBS  MaxHR  ExerciseAngina  Oldpeak
# 0   56    1        155          1    150               1      3.0
# 1   55    0        130          0    150               0      0.0
# 2   47    1        110          1    120               1      0.0
# -------------------- 分割されたデータShape --------------------
# x_train: (449, 7) x_test: (193, 7)
# y_train: (449,) y_test: (193,)
#
# -------------------- 性能評価 --------------------
#        accuracy_score  precision_score  recall_score  f1_score
# train        0.692650         0.694981      0.753138  0.722892
# test         0.694301         0.736434      0.791667  0.763052

# %% [markdown]
# ### コレステロール値を追加して比較する
# 今回は欠損値の補完は考えない<br>
# 欠損値補完は考察のもと別途考える必要がある

# %%
df = pd.read_csv('./data/train.csv')

# 前処理
pipe = PipeLine()
pipe(df)
print('-'*20, ' 変数にコレステロール値を追加', '-'*20)
display(pipe.df_num.head(3))
pack = pipe.fold_out_split(test_size=0.3)  # x_train, x_test, y_train, y_test = pack

# サポートベクターマシンでモデルを訓練
model = SVC()
model.fit(pack[0], pack[2])

# 予測値を出力
print()
print('-'*20, '性能評価', '-'*20)
display(evaluations(model, *pack))
# Out:
# --------------------  変数にコレステロール値を追加 --------------------
#    Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  ExerciseAngina  Oldpeak
# 0   56    1        155          342          1    150               1      3.0
# 1   55    0        130          394          0    150               0      0.0
# 2   47    1        110            0          1    120               1      0.0
# -------------------- 分割されたデータShape --------------------
# x_train: (449, 8) x_test: (193, 8)
# y_train: (449,) y_test: (193,)
#
# -------------------- 性能評価 --------------------
#        accuracy_score  precision_score  recall_score  f1_score
# train        0.750557         0.774892      0.748954  0.761702
# test         0.704663         0.773913      0.741667  0.757447

# %% [markdown]
# 訓練誤差は5%ほど向上したが検証誤差は1%ほどしか向上してないが改善がみられた

# %% [markdown]
# >
# ### ベースラインの標準化
# コレステロールを含めたベースラインの説明変数に標準化を取り入れる

# %%
df = pd.read_csv('./data/train.csv')

# 前処理
pipe = PipeLine()
pipe(df)
pipe.standard_scaler()  # 標準化の処理を追加
pack = pipe.fold_out_split(test_size=0.3)

# サポートベクターマシンでモデルを訓練
model = SVC()
model.fit(pack[0], pack[2])  # x_train, x_test, y_train, y_test = pack

# 予測値を出力
print()
print('-'*20, '性能評価', '-'*20)
display(evaluations(model, *pack))
# Out:
# -------------------- 標準化されたdf_num --------------------
#         Age       Sex  RestingBP  Cholesterol  FastingBS     MaxHR  \
# 0  0.256306  0.520852   1.272672     1.323176   1.742910  0.512265
# 1  0.151431 -1.919930  -0.116784     1.796972  -0.573753  0.512265
# 2 -0.687567  0.520852  -1.228348    -1.792941   1.742910 -0.706992
#
#    ExerciseAngina   Oldpeak
# 0        1.252198  1.959903
# 1       -0.798596 -0.809353
# 2        1.252198 -0.809353
# -------------------- 分割されたデータShape --------------------
# x_train: (449, 8) x_test: (193, 8)
# y_train: (449,) y_test: (193,)
#
# -------------------- 性能評価 --------------------
#        accuracy_score  precision_score  recall_score  f1_score
# train        0.864143         0.893805      0.845188  0.868817
# test         0.823834         0.898148      0.808333  0.850877

# %% [markdown]
# 標準化を施すことで<span style="color: orange;">ベースラインより精度が10%以上向上</span>していることがわかる
# >

# %% [markdown]
# # One Hot Encodeを追加（SVCモデル）
# ベースラインで取り除いたカテゴリ変数をOne_Hot_Encodingで説明変数に取り入れて比較する<br>
# (比較を行うために標準化は行わない)

# %%
df = pd.read_csv('./data/train.csv')
# 前処理
pipe = PipeLine()
pipe(df)
# pipeのカテゴリデータを保持したアトリビュートからカラム名を取得
one_hot_columns = pipe.df_cat.columns
pipe.one_hot(one_hot_columns)  # pipeのクラスメソッドでワンホット化
pack = pipe.fold_out_split(test_size=0.3)

# サポートベクターマシンでモデルを訓練
model = SVC()
model.fit(pack[0], pack[2])  # x_train, x_test, y_train, y_test = pack

# 予測値を出力
print()
print('-'*20, '性能評価', '-'*20)
display(evaluations(model, *pack))
# Out:
# -------------------- ワンホットされたカラムIndex(['ChestPainType', 'RestingECG', 'ST_Slope'], dtype='object') --------------------
#    Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  ExerciseAngina  \
# 0   56    1        155          342          1    150               1
# 1   55    0        130          394          0    150               0
# 2   47    1        110            0          1    120               1
#
#    Oldpeak  ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  \
# 0      3.0                  1                  0                  0
# 1      0.0                  0                  1                  0
# 2      0.0                  0                  0                  1
#
#    ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  RestingECG_ST  \
# 0                 0               0                  1              0
# 1                 0               1                  0              0
# 2                 0               0                  1              0
#
#    ST_Slope_Down  ST_Slope_Flat  ST_Slope_Up
# 0              0              1            0
# 1              0              0            1
# 2              0              1            0
# -------------------- 分割されたデータShape --------------------
# x_train: (449, 18) x_test: (193, 18)
# y_train: (449,) y_test: (193,)
#
# -------------------- 性能評価 --------------------
#        accuracy_score  precision_score  recall_score  f1_score
# train        0.752784         0.778261      0.748954  0.763326
# test         0.699482         0.771930      0.733333  0.752137

# %% [markdown]
# 訓練誤差は向上しているが汎化誤差はベースラインとほぼ一緒<br>むしろ悪い
# >
# 以下は各カテゴリを別々で追加して精度を確認

# %%
df = pd.read_csv('./data/train.csv')
pipe = PipeLine()
pipe(df)
one_hot_columns = pipe.df_cat.columns  # カテゴリデータのカラムを取得

# それぞれのカラムがどのように影響するか調べていく
for cat in one_hot_columns:
    print('#'*45, f'{cat}', '#'*45)
    # データ処理
    pipe = PipeLine()  # インスタンスの初期化
    pipe.viewer = False  # 前処理過程を非表示。表示する場合はコメントアウト
    pipe(df) 
    pipe.one_hot(cat)
    pack = pipe.fold_out_split(test_size=0.3)

    # サポートベクターマシンでモデルを訓練
    model = SVC()
    model.fit(pack[0], pack[2])  # x_train, x_test, y_train, y_test = pack

    # 予測値を出力
    print()
    print('-'*20, '性能評価', '-'*20)
    display(evaluations(model, *pack))
# Out:
# ############################################# ChestPainType #############################################
#
# -------------------- 性能評価 --------------------
#        accuracy_score  precision_score  recall_score  f1_score
# train        0.755011         0.779221      0.753138  0.765957
# test         0.699482         0.771930      0.733333  0.752137
# ############################################# RestingECG #############################################
#
# -------------------- 性能評価 --------------------
#        accuracy_score  precision_score  recall_score  f1_score
# train        0.752784         0.775862      0.753138  0.764331
# test         0.699482         0.771930      0.733333  0.752137
# ############################################# ST_Slope #############################################
#
# -------------------- 性能評価 --------------------
#        accuracy_score  precision_score  recall_score  f1_score
# train        0.752784         0.775862      0.753138  0.764331
# test         0.699482         0.771930      0.733333  0.752137

# %% [markdown]
# 標準化していないためかカテゴリ変数の効果は薄いよう<br>
# モデルの表現力不足のせいかRestingECGとST_Slopeの結果に変化がない

# %% [markdown]
# ### 標準化とワンホットエンコーディング（SVC)
# 標準化をしたものにワンホットエンコードがどのように寄与するか確認する

# %%
df = pd.read_csv('./data/train.csv')
# 前処理
pipe = PipeLine()
pipe(df)
one_hot_columns = pipe.df_cat.columns
pipe.one_hot(one_hot_columns)
pipe.standard_scaler()  # 標準化の処理を追加
pack = pipe.fold_out_split(test_size=0.3)

# サポートベクターマシンでモデルを訓練
model = SVC()
model.fit(pack[0], pack[2])  # x_train, x_test, y_train, y_test = pack

# 予測値を出力
print()
print('-'*20, '性能評価', '-'*20)
display(evaluations(model, *pack))
# Out:
# -------------------- ワンホットされたカラムIndex(['ChestPainType', 'RestingECG', 'ST_Slope'], dtype='object') --------------------
#    Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  ExerciseAngina  \
# 0   56    1        155          342          1    150               1
# 1   55    0        130          394          0    150               0
# 2   47    1        110            0          1    120               1
#
#    Oldpeak  ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  \
# 0      3.0                  1                  0                  0
# 1      0.0                  0                  1                  0
# 2      0.0                  0                  0                  1
#
#    ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  RestingECG_ST  \
# 0                 0               0                  1              0
# 1                 0               1                  0              0
# 2                 0               0                  1              0
#
#    ST_Slope_Down  ST_Slope_Flat  ST_Slope_Up
# 0              0              1            0
# 1              0              0            1
# 2              0              1            0
# -------------------- 標準化されたdf_num --------------------
#         Age       Sex  RestingBP  Cholesterol  FastingBS     MaxHR  \
# 0  0.256306  0.520852   1.272672     1.323176   1.742910  0.512265
# 1  0.151431 -1.919930  -0.116784     1.796972  -0.573753  0.512265
# 2 -0.687567  0.520852  -1.228348    -1.792941   1.742910 -0.706992
#
#    ExerciseAngina   Oldpeak  ChestPainType_ASY  ChestPainType_ATA  \
# 0        1.252198  1.959903           0.913392          -0.484371
# 1       -0.798596 -0.809353          -1.094820           2.064533
# 2        1.252198 -0.809353          -1.094820          -0.484371
#
#    ChestPainType_NAP  ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  \
# 0          -0.549756         -0.183892       -0.481919           0.785575
# 1          -0.549756         -0.183892        2.075039          -1.272953
# 2           1.818990         -0.183892       -0.481919           0.785575
#
#    RestingECG_ST  ST_Slope_Down  ST_Slope_Flat  ST_Slope_Up
# 0      -0.489267      -0.287456       1.015700    -0.871151
# 1      -0.489267      -0.287456      -0.984543     1.147907
# 2      -0.489267      -0.287456       1.015700    -0.871151
# -------------------- 分割されたデータShape --------------------
# x_train: (449, 18) x_test: (193, 18)
# y_train: (449,) y_test: (193,)
#
# -------------------- 性能評価 --------------------
#        accuracy_score  precision_score  recall_score  f1_score
# train        0.917595         0.913934      0.933054  0.923395
# test         0.870466         0.874016      0.925000  0.898785

# %% [markdown]
# 標準化を施したベースライン(ワンホットなし)に比べて<span style="color: orange;">5%ほど検証データの正解率が向上</span>
# >
# 以下はカテゴリ別で精度の向上を確認

# %%
df = pd.read_csv('./data/train.csv')
pipe = PipeLine()
pipe(df)
one_hot_columns = pipe.df_cat.columns  # カテゴリデータのカラムを取得

# それぞれのカラムがどのように影響するか調べていく
for cat in one_hot_columns:
    print('#'*45, f'{cat}', '#'*45)
    pipe = PipeLine()  # インスタンスの初期化
    pipe.viewer = False  # 途中処理過程を非表示。表示する場合はコメントアウト
    pipe(df) 
    pipe.one_hot(cat)
    pipe.standard_scaler()
    pack = pipe.fold_out_split(test_size=0.3)

    # サポートベクターマシンでモデルを訓練
    model = SVC()
    model.fit(pack[0], pack[2])  # x_train, x_test, y_train, y_test = pack

    # 予測値を出力
    print()
    print('-'*20, '性能評価', '-'*20)
    display(out_put(model, *pack))
# Out:
# ############################################# ChestPainType #############################################
#
# -------------------- 性能評価 --------------------
#        accuracy_score  precision_score  recall_score  f1_score
# train        0.868597         0.875000      0.878661  0.876827
# test         0.844560         0.868852      0.883333  0.876033
# ############################################# RestingECG #############################################
#
# -------------------- 性能評価 --------------------
#        accuracy_score  precision_score  recall_score  f1_score
# train        0.879733         0.914798      0.853556  0.883117
# test         0.803109         0.859649      0.816667  0.837607
# ############################################# ST_Slope #############################################
#
# -------------------- 性能評価 --------------------
#        accuracy_score  precision_score  recall_score  f1_score
# train        0.902004         0.901235      0.916318  0.908714
# test         0.886010         0.895161      0.925000  0.909836

# %% [markdown]
# 適合率、再現率ともに<span style="color: orange;">ST_Slopeの効果がかなり大きい</span><br>
# 次いでChestPainType

# %% [markdown]
# # 分類木による評価

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('./data/train.csv')
# 前処理
pipe = PipeLine()
pipe(df)
one_hot_columns = pipe.df_cat.columns
pipe.standard_scaler()  # 標準化の処理を追加
pack = pipe.fold_out_split(test_size=0.3)

# 決定木のモデルを訓練
model = DecisionTreeClassifier(max_depth=3)
model.fit(pack[0], pack[2])  # x_train, x_test, y_train, y_test = pack

# 予測値を出力
print()
print('-'*20, '性能評価', '-'*20)
display(evaluations(model, *pack))
print('-'*20, ' 説明変数の重要度 ', '-'*20)
display(pd.DataFrame([model.feature_importances_], columns=pipe.df_num.columns))
print()
# Out:
# -------------------- 標準化されたdf_num --------------------
#         Age       Sex  RestingBP  Cholesterol  FastingBS     MaxHR  \
# 0  0.256306  0.520852   1.272672     1.323176   1.742910  0.512265
# 1  0.151431 -1.919930  -0.116784     1.796972  -0.573753  0.512265
# 2 -0.687567  0.520852  -1.228348    -1.792941   1.742910 -0.706992
#
#    ExerciseAngina   Oldpeak
# 0        1.252198  1.959903
# 1       -0.798596 -0.809353
# 2        1.252198 -0.809353
# -------------------- 分割されたデータShape --------------------
# x_train: (449, 8) x_test: (193, 8)
# y_train: (449,) y_test: (193,)
#
# -------------------- 性能評価 --------------------
#        accuracy_score  precision_score  recall_score  f1_score
# train        0.817372         0.894472      0.744770  0.812785
# test         0.766839         0.912088      0.691667  0.786730
# --------------------  説明変数の重要度  --------------------
#         Age  Sex  RestingBP  Cholesterol  FastingBS     MaxHR  ExerciseAngina  \
# 0  0.077465  0.0        0.0     0.263856   0.028652  0.090309        0.532049
#
#     Oldpeak
# 0  0.007669

# %%
df = pd.read_csv('./data/train.csv')
# 前処理
pipe = PipeLine()
pipe(df)
one_hot_columns = pipe.df_cat.columns
pipe.one_hot(one_hot_columns)
pipe.standard_scaler()  # 標準化の処理を追加
pack = pipe.fold_out_split(test_size=0.3)

# 決定木のモデルを訓練
model = DecisionTreeClassifier(max_depth=3)
model.fit(pack[0], pack[2])  # x_train, x_test, y_train, y_test = pack

# 予測値を出力
print()
print('-'*20, '性能評価', '-'*20)
display(evaluations(model, *pack))
print('-'*20, ' 説明変数の重要度 ', '-'*20)
display(pd.DataFrame([model.feature_importances_], columns=pipe.df_num.columns))
print()
# Out:
# -------------------- ワンホットされたカラムIndex(['ChestPainType', 'RestingECG', 'ST_Slope'], dtype='object') --------------------
#    Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  ExerciseAngina  \
# 0   56    1        155          342          1    150               1
# 1   55    0        130          394          0    150               0
# 2   47    1        110            0          1    120               1
#
#    Oldpeak  ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  \
# 0      3.0                  1                  0                  0
# 1      0.0                  0                  1                  0
# 2      0.0                  0                  0                  1
#
#    ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  RestingECG_ST  \
# 0                 0               0                  1              0
# 1                 0               1                  0              0
# 2                 0               0                  1              0
#
#    ST_Slope_Down  ST_Slope_Flat  ST_Slope_Up
# 0              0              1            0
# 1              0              0            1
# 2              0              1            0
# -------------------- 標準化されたdf_num --------------------
#         Age       Sex  RestingBP  Cholesterol  FastingBS     MaxHR  \
# 0  0.256306  0.520852   1.272672     1.323176   1.742910  0.512265
# 1  0.151431 -1.919930  -0.116784     1.796972  -0.573753  0.512265
# 2 -0.687567  0.520852  -1.228348    -1.792941   1.742910 -0.706992
#
#    ExerciseAngina   Oldpeak  ChestPainType_ASY  ChestPainType_ATA  \
# 0        1.252198  1.959903           0.913392          -0.484371
# 1       -0.798596 -0.809353          -1.094820           2.064533
# 2        1.252198 -0.809353          -1.094820          -0.484371
#
#    ChestPainType_NAP  ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  \
# 0          -0.549756         -0.183892       -0.481919           0.785575
# 1          -0.549756         -0.183892        2.075039          -1.272953
# 2           1.818990         -0.183892       -0.481919           0.785575
#
#    RestingECG_ST  ST_Slope_Down  ST_Slope_Flat  ST_Slope_Up
# 0      -0.489267      -0.287456       1.015700    -0.871151
# 1      -0.489267      -0.287456      -0.984543     1.147907
# 2      -0.489267      -0.287456       1.015700    -0.871151
# -------------------- 分割されたデータShape --------------------
# x_train: (449, 18) x_test: (193, 18)
# y_train: (449,) y_test: (193,)
#
# -------------------- 性能評価 --------------------
#        accuracy_score  precision_score  recall_score  f1_score
# train        0.879733         0.883817      0.891213  0.887500
# test         0.854922         0.877049      0.891667  0.884298
# --------------------  説明変数の重要度  --------------------
#    Age       Sex  RestingBP  Cholesterol  FastingBS     MaxHR  ExerciseAngina  \
# 0  0.0  0.007564        0.0          0.0        0.0  0.032009             0.0
#
#     Oldpeak  ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  \
# 0  0.101312           0.203358                0.0                0.0
#
#    ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  RestingECG_ST  \
# 0               0.0             0.0                0.0            0.0
#
#    ST_Slope_Down  ST_Slope_Flat  ST_Slope_Up
# 0            0.0            0.0     0.655757

# %%
df = pd.read_csv('./data/train.csv')
pipe = PipeLine()
pipe(df)
one_hot_columns = pipe.df_cat.columns  # カテゴリデータのカラムを取得

# それぞれのカラムがどのように影響するか調べていく
for cat in one_hot_columns:
    print('#'*45, f'{cat}', '#'*45)
    pipe = PipeLine()  # インスタンスの初期化
    pipe.viewer = False  # 前処理の過程を非表示にできる
    pipe(df) 
    pipe.one_hot(cat)
    pipe.standard_scaler()
    pack = pipe.fold_out_split(test_size=0.3)

    model = DecisionTreeClassifier(max_depth=3)
    model.fit(pack[0], pack[2])  # x_train, x_test, y_train, y_test = pack

    # 予測値を出力
    # 予測値を出力
    print()
    print('-'*20, '性能評価', '-'*20)
    display(evaluations(model, *pack))
    print('-'*20, ' 説明変数の重要度 ', '-'*20)
    display(pd.DataFrame([model.feature_importances_], columns=pipe.df_num.columns))
    print()
# Out:
# ############################################# ChestPainType #############################################
#
# -------------------- 性能評価 --------------------
#        accuracy_score  precision_score  recall_score  f1_score
# train        0.815145         0.825000      0.828452  0.826722
# test         0.772021         0.806452      0.833333  0.819672
# --------------------  説明変数の重要度  --------------------
#    Age       Sex  RestingBP  Cholesterol  FastingBS     MaxHR  ExerciseAngina  \
# 0  0.0  0.087394        0.0     0.081464        0.0  0.033667             0.0
#
#     Oldpeak       ASY  ATA  NAP   TA
# 0  0.172791  0.624684  0.0  0.0  0.0
# ############################################# RestingECG #############################################
#
# -------------------- 性能評価 --------------------
#        accuracy_score  precision_score  recall_score  f1_score
# train        0.817372         0.894472       0.74477  0.812785
# test         0.772021         0.913043       0.70000  0.792453
# --------------------  説明変数の重要度  --------------------
#         Age  Sex  RestingBP  Cholesterol  FastingBS     MaxHR  ExerciseAngina  \
# 0  0.077465  0.0        0.0     0.246032   0.028652  0.090309        0.532049
#
#     Oldpeak  LVH  Normal        ST
# 0  0.007669  0.0     0.0  0.017824
# ############################################# ST_Slope #############################################
#
# -------------------- 性能評価 --------------------
#        accuracy_score  precision_score  recall_score  f1_score
# train        0.859688         0.896396      0.832636  0.863341
# test         0.849741         0.876033      0.883333  0.879668
# --------------------  説明変数の重要度  --------------------
#    Age       Sex  RestingBP  Cholesterol  FastingBS     MaxHR  ExerciseAngina  \
# 0  0.0  0.030911        0.0     0.109583   0.030789  0.057872             0.0
#
#     Oldpeak  Down  Flat        Up
# 0  0.075718   0.0   0.0  0.695127
